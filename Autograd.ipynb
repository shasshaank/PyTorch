# %%
import torch

x = torch.ones(5)
y = torch.zeros(3)
w = torch.rand(5,3,requires_grad=True)
b = torch.rand(3,requires_grad=True)
z = torch.matmul(x,w)+b
loss = torch.nn.functional.binary_cross_entropy_with_logits(z,y)

# %%
print(f"Gradient function for z = {z.grad_fn}")
print(f"Gradient function for loss = {loss.grad_fn}")
# Out:
# Gradient function for z = <AddBackward0 object at 0x7d366f2043d0>
# Gradient function for loss = <BinaryCrossEntropyWithLogitsBackward0 object at 0x7d366f2ba110>

# %%
loss.backward()
print(w.grad)
print(b.grad)
# Out:
# tensor([[0.3153, 0.3164, 0.3226],
#         [0.3153, 0.3164, 0.3226],
#         [0.3153, 0.3164, 0.3226],
#         [0.3153, 0.3164, 0.3226],
#         [0.3153, 0.3164, 0.3226]])
# tensor([0.3153, 0.3164, 0.3226])

# %%
z = torch.matmul(x,w)+b
print(z.requires_grad)

with torch.no_grad():
  z = torch.matmul(x,w)+b
print(z.requires_grad)
# Out:
# True
# False

# %%
z = torch.matmul(x,w)+b
z_det = z.detach()
print(z_det.requires_grad)
# Out:
# False
